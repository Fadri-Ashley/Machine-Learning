# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("dataset/multiple_linear_regression_dataset.csv")
df
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
X = df[['age', 'experience']]
y = df['income']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
print("Intercept: ", model.intercept_)
print("Coefficient: ", model.coef_)
# Out:
# Intercept:  31261.689854101278
# Coefficient:  [ -99.19535546 2162.40419192]

# %%
print("Prediction: ", model.predict([[43, 10]]))
# Out:
# Prediction:  [48620.33148852]
# C:\Users\Fadri\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X['age'], X['experience'], y)

ax.set_xlabel("age")
ax.set_ylabel("experience")
ax.set_zlabel("income")

plt.show()
